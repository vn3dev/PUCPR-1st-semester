# %%
nome = int(input("insira o numero"))

par = bool(nome % 2 == 0)
print(f"is even: {par}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 nome = int(input("insira o numero"))
#       3 par = bool(nome % 2 == 0)
#       4 print(f"is even: {par}")
#
# File c:\Users\vinic\Desktop\PUCPR-1st-semester\matematica-aplicada\venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# ...

# %%
num = 9.455555

print(f"preço é: {num:.2f}")
# Out:
# preço é: 9.46

# %%
a, b = 3, 8
c, d = 3, 8

a = b
b = a

print(a, b)

c, d = d, c

print(c, d)
# Out:
# 8 8
# 8 3

# %%
PI = 3.141592653589793
RAIO = float(input("insira raio: "))

area = PI * (RAIO ** 2)
print(area)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 PI = 3.141592653589793
# ----> 2 RAIO = float(input("insira raio: "))
#       4 area = PI * (RAIO ** 2)
#       5 print(area)
#
# ValueError: could not convert string to float: ''

# %%
celsius = float(input("insira temp em celsius"))

print(celsius * 1.8 + 32)
# Out:
# 86.0

# %%
nome = "Python"

for letter in range(5):
    print(nome[letter])
# Out:
# n
# o
# h
# t
# y

# %%
nome = "Antedeguemon"

print(nome[0:2])
print(nome[0:4])
print(nome[5:7])
# Out:
# An
# Ante
# deg

# %%
nome = "Antedeguemon"

print(nome[:3])
print(nome[3:])
print(nome[:])
# Out:
# Ant
# edeguemon
# Antedeguemon

# %%
nome = "Antedeguemon"

print(nome[0:9:2])
print(nome[::2])
# Out:
# Atdge
# Atdgeo

# %%
nomeComp = input("escreva nome completo: ")
nome = nomeComp.split()

print(f"Array do nome: {nome}")
print(f"Primeiro nome: {nome[0]}")
print(f"Segundo nome: {nome[1]}")
print(f"Segunda letra primeiro nome: {nome[0][1]}")
# Out:
# Array do nome: ['mi', 'bombo', 'clat']
# Primeiro nome: i
# Segundo nome: bombo

# %%
numero = float(input("insira um numero"))

print(f"Elevado ao quadrado: {numero ** 2}")
print(f"Elevado ao cubo: {numero ** 3}")
print(f"Raiz quadrada: {numero ** 0.5}")
# Out:
# Elevado ao quadrado: 16.0
# Elevado ao cubo: 64.0
# Raiz quadrada: 2.0

# %%
base = float(input("Insira a base"))
altura = float(input("Insira altura"))

print(f"A area eh: {(base * altura)/2}")

# %%
reais = float(input("Insira o valor"))

print(f"{reais * 5.19}")
# Out:
# 34.51350000000001

# %%
nome = input("Insira o nome")

print(f"Três primeiras letras: {nome[0:3]}")
# Out:
# Três primeiras letras: vin
