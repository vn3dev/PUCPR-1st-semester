# %%
nome = int(input("numero hetero"))

par = bool(nome % 2 == 0)
print(f"is even: {par}")
# Out:
# is even: True

# %%
num = 9.455555

print(f"preço é: {num:.2f}")
# Out:
# preço é: 9.46

# %%
a, b = 3, 8
c, d = 3, 8

a = b
b = a

print(a, b)

c, d = d, c

print(c, d)
# Out:
# 8 8
# 8 3

# %%
PI = 3.141592653589793
RAIO = float(input("insira raio: "))

area = PI * (RAIO ** 2)
print(area)
# Out:
# 201.06192982974676
